# %% [markdown]
# **TUPLES**

# %% [markdown]
# **Creating Tuples**

# %%
a = tuple()
b = (1,2,3)
c = ()

# %% [markdown]
# **Tuple Operations**

# %%
b.count(2)
# Out:
# 1

# %%
b.index(2)
# Out:
# 1

# %% [markdown]
# **SETS**

# %% [markdown]
# **Creating Sets**

# %%
#No Indexing in sets
A = {'A','B'}
type(A)
# Out:
# set

# %%
#No Repeatation
A = set(['A','B','A'])
A
# Out:
# {'A', 'B'}

# %% [markdown]
# **Set Methods**

# %%
#Append operation
A.add('L')
A
# Out:
# {'A', 'B', 'L'}

# %%
#Difference of two sets
A = {'A', 'B', 'L'}
B = {'c', 'K', 'L'}
A-B
# Out:
# {'A', 'B'}

# %%
B-A
# Out:
# {'K', 'c'}

# %%
A.difference(B) #Equal to A-B
# Out:
# {'A', 'B'}

# %%
A.difference_update(B) #A=A-B
A
# Out:
# {'A', 'B'}
